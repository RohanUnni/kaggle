# %%
import numpy as np 
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt  
import seaborn as sns
from scipy import stats
#For some Statistics
from scipy.stats import norm, skew
from sklearn.preprocessing import Imputer
from mpl_toolkits.mplot3d import Axes3D
train=pd.read_csv('train_class.csv')
test=pd.read_csv('test_class_1.csv')
train.drop("Unnamed: 0",axis=1,inplace=True)
train.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   880          20       RL          NaN     7000   Pave   NaN      IR1
# 1  1147          20       RL          NaN    11200   Pave   NaN      Reg
# 2  1347          20       RL          NaN    20781   Pave   NaN      IR2
# 3  1081          20       RL         80.0    11040   Pave   NaN      Reg
# 4   229          20       RL         70.0     8521   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   GdWo         NaN       0
# 1         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN  MnPrv         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      7   2009        WD         Normal     136500
# 1      5   2006        WD         Normal     180000
# 2      6   2006        WD         Normal     262500
# 3     10   2008       COD        Abnorml     145000
# 4      5   2010        WD         Normal     125000
#
# [5 rows x 81 columns]

# %%
#% FIll rate
total = train.isnull().sum(axis=0).sort_values(ascending=False)
percent = (train.isnull().sum(axis=0)/train.isnull().count(axis=0)).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total_missing_values_per_column', 'Percent'])
missing_data.head(20)
# Out:
#               Total_missing_values_per_column   Percent
# PoolQC                                   1161  0.994007
# MiscFeature                              1123  0.961473
# Alley                                    1099  0.940925
# Fence                                     955  0.817637
# FireplaceQu                               554  0.474315
# LotFrontage                               209  0.178938
# GarageCond                                 70  0.059932
# GarageType                                 70  0.059932
# GarageYrBlt                                70  0.059932
# GarageFinish                               70  0.059932
# GarageQual                                 70  0.059932
# BsmtExposure                               32  0.027397
# BsmtFinType1                               31  0.026541
# BsmtCond                                   31  0.026541
# BsmtQual                                   31  0.026541
# BsmtFinType2                               31  0.026541
# MasVnrArea                                  8  0.006849
# MasVnrType                                  8  0.006849
# Electrical                                  1  0.000856
# LandSlope                                   0  0.000000

# %%
#Drop Columns
#train.drop(["PoolQC","Alley","MiscFeature","Fence","FireplaceQu"],axis=1,inplace=True)
train.dropna(how='all')
print("Rows dropped with entire Nan Values")
# Out:
# Rows dropped with entire Nan Values

# %%
#EDA

# %%
num=list(train._get_numeric_data().columns)

# %%
categorical_feature_columns = list(set(train.columns) - set(train._get_numeric_data().columns))
#categorical_feature_columns

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1168.000000  1168.000000   959.000000    1168.000000  1168.000000
# mean    732.310788    57.059075    70.185610   10359.635274     6.078767
# std     424.868026    42.904139    24.897723    7735.250081     1.390614
# min       2.000000    20.000000    21.000000    1477.000000     1.000000
# 25%     356.750000    20.000000    59.000000    7559.500000     5.000000
# 50%     728.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1105.250000    70.000000    80.000000   11608.500000     7.000000
# max    1460.000000   190.000000   313.000000  159000.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1168.000000  1168.000000   1168.000000  1160.000000  1168.000000
# mean      5.565068  1971.083904   1984.714041   103.951724   449.039384
# std       1.116617    30.030059     20.566912   181.611598   463.125994
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1966.750000     0.000000     0.000000
# 50%       5.000000  1972.000000   1993.000000     0.000000   387.000000
# 75%       6.000000  2000.000000   2004.000000   166.250000   724.000000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1168.000000  1168.000000    1168.000000  1168.000000
# mean       ...          94.561644    46.458048      22.982877     3.720890
# std        ...         126.063169    65.407024      63.527441    30.749855
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.500000       0.000000     0.000000
# 75%        ...         168.000000    68.250000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1168.000000  1168.000000   1168.000000  1168.000000  1168.000000
# mean     14.964041     3.448630     49.027397     6.338185  2007.836473
# std      54.717601    44.896939    549.773118     2.740633     1.341375
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1168.000000
# mean   179999.360445
# std     78150.951647
# min     34900.000000
# 25%    129900.000000
# 50%    161625.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
train.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   880          20       RL          NaN     7000   Pave   NaN      IR1
# 1  1147          20       RL          NaN    11200   Pave   NaN      Reg
# 2  1347          20       RL          NaN    20781   Pave   NaN      IR2
# 3  1081          20       RL         80.0    11040   Pave   NaN      Reg
# 4   229          20       RL         70.0     8521   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   GdWo         NaN       0
# 1         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN  MnPrv         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      7   2009        WD         Normal     136500
# 1      5   2006        WD         Normal     180000
# 2      6   2006        WD         Normal     262500
# 3     10   2008       COD        Abnorml     145000
# 4      5   2010        WD         Normal     125000
#
# [5 rows x 81 columns]

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation = 45)
sns.boxplot('Neighborhood', 'SalePrice', data=train)

# %%
#IMPUTATION

# %%
#train["PoolQC"] = train["PoolQC"].fillna("None")
#train["MiscFeature"] = train["MiscFeature"].fillna("None")
for col in ('MiscFeature','Alley','Fence'):
    train[col]=train[col].fillna("None")
for col in ('PoolQC','GarageYrBlt', 'GarageArea', 'GarageCars'):
    train[col] = train[col].fillna(0)
print(train[['PoolQC','MiscFeature','Alley','Fence',"GarageYrBlt","GarageArea","GarageCars"]])
# Out:
#      PoolQC MiscFeature Alley  Fence  GarageYrBlt  GarageArea  GarageCars
# 0         0        None  None   GdWo       1978.0         336           1
# 1         0        None  None   None       1985.0         403           2
# 2         0        None  None   None       1968.0         508           2
# 3         0        None  None   None       1971.0         528           2
# 4         0        None  None  MnPrv       1974.0         336           1
# 5         0        None  None   None       1963.0         516           2
# 6         0        None  None  MnPrv       1922.0         240           1
# 7         0        None  None   None       1977.0         619           2
# 8         0        None  None   None       1971.0         264           1
# 9         0        None  None   None       1966.0         484           2
# 10        0        None  None   None       1969.0         540           2
# 11        0        None  None   GdWo       1959.0         484           2
# 12        0        None  None   None       2006.0         694           3
# 13        0        None  None   None       2008.0         626           2
# 14        0        None  None   None       1999.0         779           3
# 15        0        None  None   None       1957.0         294           1
# 16        0        None  Grvl   None       1940.0         210           1
# 17        0        None  None   None       2002.0         765           3
# 18        0        Shed  None   None       1989.0         660           2
# 19        0        None  None   None          0.0           0           0
# 20        0        None  None   None       2003.0         474           2
# 21        0        None  None   None       1998.0         576           2
# 22        0        None  None   None       1961.0         261           1
# 23        0        None  None  MnPrv       1970.0         530           2
# 24        0        None  None   None       2005.0         397           2
# 25        0        None  None   None       2004.0         434           2
# 26        0        None  None   None       2007.0         895           3
# 27        0        None  None   None       1939.0         240           1
# 28        0        None  None  MnPrv       1939.0         240           1
# 29        0        None  None   None       2007.0         648           3
# ...     ...         ...   ...    ...          ...         ...         ...
# 1138      0        None  None  MnPrv       1963.0         480           2
# 1139      0        None  None   None       1997.0         508           2
# 1140      0        None  None  MnPrv       1981.0         280           1
# 1141      0        None  None   None       2003.0         555           2
# 1142      0        None  None   None       1960.0         498           2
# 1143      0        None  None   None       1996.0         527           2
# 1144      0        None  None   None       2008.0         860           3
# 1145      0        None  None   None       2005.0         676           3
# 1146      0        None  None   None          0.0           0           0
# 1147      0        None  None   None       2006.0         648           3
# 1148      0        None  None   None       1976.0         512           2
# 1149      0        None  None   None       1971.0         440           2
# 1150      0        None  None   None       1977.0         544           2
# 1151      0        None  None   None       1977.0         505           2
# 1152      0        None  None   None       1996.0         500           2
# 1153      0        None  None   None       1972.0         338           1
# 1154      0        None  None   None       2005.0         525           2
# 1155      0        None  None   None       2000.0         663           2
# 1156      0        None  None   None       2007.0         578           2
# 1157      0        None  None   None       1994.0         343           2
# 1158      0        None  None   None       1980.0         528           2
# 1159      0        None  None   None       2003.0         670           2
# 1160      0        None  None   None       1962.0         288           1
# 1161      0        None  None   None       1951.0         240           1
# 1162      0        None  None   None       1994.0         471           2
# 1163      0        Shed  None  GdPrv       1992.0         462           2
# 1164      0        None  None   None       1997.0         870           3
# 1165      0        None  None   None       1976.0         440           2
# 1166      0        None  None   None       1975.0        1356           4
# 1167      0        None  None   None       1991.0         280           1
#
# [1168 rows x 7 columns]

# %%
# Imputation Using Imputer
imp_mean = Imputer(missing_values = 'NaN', strategy='mean')
imp_mean.fit(train[['LotFrontage']])
train['LotFrontage'] = imp_mean.transform(train[['LotFrontage']])
imp_mean.fit(train[['MasVnrArea']])
train['MasVnrArea'] = imp_mean.transform(train[['MasVnrArea']])
print(train["MasVnrArea"])


#Mode value imputation
for col in ('FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond','BsmtExposure', 'BsmtQual', 'BsmtFinType2', 'BsmtCond', 'BsmtFinType1','MasVnrType', 'Electrical'):
    train[col] = train[col].fillna(train[col].mode()[0])
print(train[col])
# Out:
# 0        90.000000
# 1        85.000000
# 2         0.000000
# 3       144.000000
# 4         0.000000
# 5         0.000000
# 6         0.000000
# 7       424.000000
# 8       604.000000
# 9       252.000000
# 10        0.000000
# 11        0.000000
# 12      772.000000
# 13      166.000000
# 14      165.000000
# 15        0.000000
# 16        0.000000
# 17      630.000000
# 18        0.000000
# 19        0.000000
# 20      106.000000
# 21        0.000000
# 22      192.000000
# 23      288.000000
# 24       11.000000
# 25        0.000000
# 26      428.000000
# 27        0.000000
# 28      252.000000
# 29       72.000000
#            ...
# 1138    156.000000
# 1139    215.000000
# 1140      0.000000
# 1141    103.951724
# 1142     30.000000
# 1143    338.000000
# 1144    270.000000
# 1145    200.000000
# 1146      0.000000
# 1147     72.000000
# 1148    360.000000
# 1149    376.000000
# 1150    209.000000
# 1151    299.000000
# 1152      0.000000
# 1153      0.000000
# 1154     82.000000
# 1155      0.000000
# 1156      0.000000
# 1157      0.000000
# 1158      0.000000
# 1159      0.000000
# 1160    116.000000
# 1161    600.000000
# 1162    105.000000
# 1163      0.000000
# 1164    423.000000
# 1165      0.000000
# 1166    149.000000
# 1167    142.000000
# Name: MasVnrArea, Length: 1168, dtype: float64
# 0       SBrkr
# 1       SBrkr
# 2       SBrkr
# 3       SBrkr
# 4       SBrkr
# 5       SBrkr
# 6       SBrkr
# 7       SBrkr
# 8       SBrkr
# 9       SBrkr
# 10      SBrkr
# 11      SBrkr
# 12      SBrkr
# 13      SBrkr
# 14      SBrkr
# 15      SBrkr
# 16      SBrkr
# 17      SBrkr
# 18      SBrkr
# 19      SBrkr
# 20      SBrkr
# 21      SBrkr
# 22      SBrkr
# 23      SBrkr
# 24      SBrkr
# 25      SBrkr
# 26      SBrkr
# 27      SBrkr
# 28      SBrkr
# 29      SBrkr
#         ...
# 1138    SBrkr
# 1139    SBrkr
# 1140    SBrkr
# 1141    SBrkr
# 1142    FuseA
# 1143    SBrkr
# 1144    SBrkr
# 1145    SBrkr
# 1146    SBrkr
# 1147    SBrkr
# 1148    SBrkr
# 1149    SBrkr
# 1150    SBrkr
# 1151    SBrkr
# 1152    SBrkr
# 1153    SBrkr
# 1154    SBrkr
# 1155    SBrkr
# 1156    SBrkr
# 1157    SBrkr
# 1158    FuseA
# 1159    SBrkr
# 1160    SBrkr
# 1161    FuseF
# 1162    SBrkr
# 1163    SBrkr
# 1164    SBrkr
# 1165    SBrkr
# 1166    SBrkr
# 1167    SBrkr
# Name: Electrical, Length: 1168, dtype: object

# %%
total = train.isnull().sum(axis=0).sort_values(ascending=False)
percent = (train.isnull().sum(axis=0)/train.isnull().count(axis=0)).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total_missing_values_per_column', 'Percent'])
missing_data.head()
#NO MISSING DATA
# Out:
#              Total_missing_values_per_column  Percent
# SalePrice                                  0      0.0
# Heating                                    0      0.0
# RoofStyle                                  0      0.0
# RoofMatl                                   0      0.0
# Exterior1st                                0      0.0

# %%
#for col in list(train.columns:
    #plt.scatter(train[col],train.SalePrice)
    #plt.title(col)
   #plt.show()

# %%
#Feature Engineering
#train["flrsqftrng"]=abs(train["2ndFlrSF"]-train["1stFlrSF"]) #Difference in area of 1st floor & 2nd floor

# %%
from sklearn.feature_selection import f_regression, mutual_info_regression
plt.figure(figsize=(10,6))
sns.heatmap(train.corr())

# %%
X = train.LotArea[:,np.newaxis]  # Reshape #creates a column vector
y = train.SalePrice


# Fitting Simple Linear Regression to the Training set

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)


# Predicting the Test set results
y_pred = regressor.predict(X)
y_pred

## Plotting the Best Fitting Line

 # Train Part
plt.scatter(X, y)
plt.plot(X, y_pred, "r-")
plt.title('Housing Price ')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
#Multivariate
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      880          20       RL     70.18561     7000   Pave  None      IR1
# 1     1147          20       RL     70.18561    11200   Pave  None      Reg
# 2     1347          20       RL     70.18561    20781   Pave  None      IR2
# 3     1081          20       RL     80.00000    11040   Pave  None      Reg
# 4      229          20       RL     70.00000     8521   Pave  None      Reg
# 5       53          90       RM    110.00000     8472   Grvl  None      IR2
# 6     1386          50       RM     40.00000     5436   Pave  None      Reg
# 7      962          60       RL     70.18561    12227   Pave  None      IR1
# 8      236         160       RM     21.00000     1680   Pave  None      Reg
# 9     1042          60       RL     70.18561     9130   Pave  None      Reg
# 10     121          80       RL     70.18561    21453   Pave  None      IR1
# 11     504          20       RL    100.00000    15602   Pave  None      IR1
# 12     478          60       RL    105.00000    13693   Pave  None      Reg
# 13     283         120       RL     34.00000     5063   Pave  None      Reg
# 14    1314          60       RL    108.00000    14774   Pave  None      IR1
# 15     255          20       RL     70.00000     8400   Pave  None      Reg
# 16     218          70       RM     57.00000     9906   Pave  Grvl      Reg
# 17     701          20       RL     85.00000    14331   Pave  None      Reg
# 18     726          20       RL     60.00000     6960   Pave  None      Reg
# 19    1144          20       RL     70.18561     9000   Pave  None      Reg
# 20    1237         160       RL     36.00000     2628   Pave  None      Reg
# 21     377          85       RL     57.00000     8846   Pave  None      IR1
# 22     610          20       RL     61.00000     7943   Pave  None      Reg
# 23     136          20       RL     80.00000    10400   Pave  None      Reg
# 24     791         120       RL     43.00000     3182   Pave  None      Reg
# 25    1129          60       RL     59.00000    11796   Pave  None      IR1
# 26    1325          20       RL     75.00000     9986   Pave  None      Reg
# 27     268          75       RL     60.00000     8400   Pave  None      Reg
# 28     800          50       RL     60.00000     7200   Pave  None      Reg
# 29     444         120       RL     53.00000     3922   Pave  None      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1138   616          85       RL     80.00000     8800   Pave  None      Reg
# 1139   477          20       RL     75.00000    13125   Pave  None      Reg
# 1140   595          20       RL     88.00000     7990   Pave  None      IR1
# 1141   937          20       RL     67.00000    10083   Pave  None      Reg
# 1142   348          20       RL     70.18561    17600   Pave  None      IR1
# 1143   749          20       RL     59.00000    10593   Pave  None      IR1
# 1144  1317          20       RL     61.00000    10226   Pave  None      IR1
# 1145   337          20       RL     86.00000    14157   Pave  None      IR1
# 1146   387          50       RL     58.00000     8410   Pave  None      Reg
# 1147   598         120       RL     53.00000     3922   Pave  None      Reg
# 1148   850          80       RL     80.00000     9600   Pave  None      Reg
# 1149   433         160       RM     24.00000     1920   Pave  None      Reg
# 1150   633          20       RL     85.00000    11900   Pave  None      Reg
# 1151   280          60       RL     83.00000    10005   Pave  None      Reg
# 1152   401         120       RL     38.00000    14963   Pave  None      IR2
# 1153   848          20       RL     36.00000    15523   Pave  None      IR1
# 1154  1298         180       RM     35.00000     3675   Pave  None      Reg
# 1155  1366          60       FV     70.18561     7500   Pave  None      Reg
# 1156   687          60       FV     84.00000    10207   Pave  None      Reg
# 1157   858          60       RL     65.00000     8125   Pave  None      Reg
# 1158  1280          50  C (all)     60.00000     7500   Pave  None      Reg
# 1159    47          50       RL     48.00000    12822   Pave  None      IR1
# 1160   117          20       RL     70.18561    11616   Pave  None      Reg
# 1161   105          50       RM     70.18561     7758   Pave  None      Reg
# 1162   921          60       RL     70.00000     8462   Pave  None      IR1
# 1163  1211          60       RL     70.00000    11218   Pave  None      Reg
# 1164   991          60       RL     82.00000     9452   Pave  None      Reg
# 1165   196         160       RL     24.00000     2280   Pave  None      Reg
# 1166  1191         190       RL     70.18561    32463   Pave  None      Reg
# 1167   226         160       RM     21.00000     1680   Pave  None      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    ...            0      0   GdWo        None
# 1            Lvl    AllPub    ...            0      0   None        None
# 2            Lvl    AllPub    ...            0      0   None        None
# 3            Lvl    AllPub    ...            0      0   None        None
# 4            Lvl    AllPub    ...            0      0  MnPrv        None
# 5            Bnk    AllPub    ...            0      0   None        None
# 6            Lvl    AllPub    ...            0      0  MnPrv        None
# 7            Lvl    AllPub    ...            0      0   None        None
# 8            Lvl    AllPub    ...            0      0   None        None
# 9            Lvl    AllPub    ...            0      0   None        None
# 10           Low    AllPub    ...            0      0   None        None
# 11           Lvl    AllPub    ...            0      0   GdWo        None
# 12           Lvl    AllPub    ...            0      0   None        None
# 13           Lvl    AllPub    ...            0      0   None        None
# 14           Lvl    AllPub    ...            0      0   None        None
# 15           Lvl    AllPub    ...            0      0   None        None
# 16           Lvl    AllPub    ...            0      0   None        None
# 17           Lvl    AllPub    ...            0      0   None        None
# 18           Lvl    AllPub    ...            0      0   None        Shed
# 19           Lvl    AllPub    ...            0      0   None        None
# 20           Lvl    AllPub    ...            0      0   None        None
# 21           Lvl    AllPub    ...            0      0   None        None
# 22           Lvl    AllPub    ...            0      0   None        None
# 23           Lvl    AllPub    ...            0      0  MnPrv        None
# 24           Lvl    AllPub    ...            0      0   None        None
# 25           Lvl    AllPub    ...            0      0   None        None
# 26           Lvl    AllPub    ...            0      0   None        None
# 27           Bnk    AllPub    ...            0      0   None        None
# 28           Lvl    AllPub    ...            0      0  MnPrv        None
# 29           Lvl    AllPub    ...            0      0   None        None
# ...          ...       ...    ...          ...    ...    ...         ...
# 1138         Lvl    AllPub    ...            0      0  MnPrv        None
# 1139         Lvl    AllPub    ...            0      0   None        None
# 1140         Lvl    AllPub    ...            0      0  MnPrv        None
# 1141         Lvl    AllPub    ...            0      0   None        None
# 1142         Lvl    AllPub    ...            0      0   None        None
# 1143         Lvl    AllPub    ...            0      0   None        None
# 1144         Lvl    AllPub    ...            0      0   None        None
# 1145         HLS    AllPub    ...            0      0   None        None
# 1146         Lvl    AllPub    ...            0      0   None        None
# 1147         Lvl    AllPub    ...            0      0   None        None
# 1148         Lvl    AllPub    ...            0      0   None        None
# 1149         Lvl    AllPub    ...            0      0   None        None
# 1150         Lvl    AllPub    ...            0      0   None        None
# 1151         Lvl    AllPub    ...            0      0   None        None
# 1152         Lvl    AllPub    ...            0      0   None        None
# 1153         Lvl    AllPub    ...            0      0   None        None
# 1154         Lvl    AllPub    ...            0      0   None        None
# 1155         Lvl    AllPub    ...            0      0   None        None
# 1156         Lvl    AllPub    ...            0      0   None        None
# 1157         Lvl    AllPub    ...            0      0   None        None
# 1158         Lvl    AllPub    ...            0      0   None        None
# 1159         Lvl    AllPub    ...            0      0   None        None
# 1160         Lvl    AllPub    ...            0      0   None        None
# 1161         Lvl    AllPub    ...            0      0   None        None
# 1162         Lvl    AllPub    ...            0      0   None        None
# 1163         Lvl    AllPub    ...            0      0  GdPrv        Shed
# 1164         Lvl    AllPub    ...            0      0   None        None
# 1165         Lvl    AllPub    ...            0      0   None        None
# 1166         Low    AllPub    ...            0      0   None        None
# 1167         Lvl    AllPub    ...            0      0   None        None
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          0      7   2009        WD         Normal     136500
# 1          0      5   2006        WD         Normal     180000
# 2          0      6   2006        WD         Normal     262500
# 3          0     10   2008       COD        Abnorml     145000
# 4          0      5   2010        WD         Normal     125000
# 5          0      5   2010        WD         Normal     110000
# 6          0      5   2010        WD         Normal     125500
# 7          0      7   2008        WD         Normal     272000
# 8          0      8   2008        WD         Normal      89500
# 9          0      7   2008        WD         Normal     173000
# 10         0     10   2006        WD         Normal     180000
# 11         0      3   2010        WD         Normal     289000
# 12         0      3   2007        WD         Normal     380000
# 13         0      4   2009     ConLw         Normal     207500
# 14         0      5   2010        WD         Normal     333168
# 15         0      6   2010        WD         Normal     145000
# 16         0      9   2006        WD         Family     107000
# 17         0      5   2006        WD         Normal     312500
# 18       500     11   2009        WD         Normal     120500
# 19         0      7   2008        WD         Normal      80000
# 20         0      6   2010        WD         Normal     175500
# 21         0      7   2006        WD         Normal     148000
# 22         0      4   2007        WD         Normal     118500
# 23         0      5   2008        WD         Normal     174000
# 24         0      9   2009        WD         Normal     160200
# 25         0      7   2007        WD         Normal     215000
# 26         0      2   2007       New        Partial     147000
# 27         0      7   2008        WD         Normal     179500
# 28         0      6   2007        WD         Normal     175000
# 29         0      6   2007       New        Partial     172500
# ...      ...    ...    ...       ...            ...        ...
# 1138       0      5   2010        WD        Abnorml     137500
# 1139       0      4   2008        WD         Normal     208900
# 1140       0      4   2008        WD         Normal     110000
# 1141       0      8   2009        WD         Normal     184900
# 1142       0     12   2009        WD         Normal     157500
# 1143       0      3   2010        WD         Normal     260400
# 1144       0      1   2009        WD         Normal     295493
# 1145       0      7   2007        WD         Normal     377426
# 1146       0      5   2006        WD        AdjLand      81000
# 1147       0      2   2007       New        Partial     194201
# 1148       0      8   2007        WD         Normal     187000
# 1149       0      8   2007        WD         Normal     122500
# 1150       0      4   2009        WD         Family      82500
# 1151       0      3   2008        WD         Normal     192000
# 1152       0     12   2008        WD         Normal     245500
# 1153       0      8   2009        WD         Normal     133500
# 1154       0      6   2006       New        Partial     140000
# 1155       0      1   2010        WD         Normal     216000
# 1156       0      8   2007       New        Partial     227875
# 1157       0      3   2009        WD         Normal     174000
# 1158       0      4   2010       COD        Abnorml      68400
# 1159       0      8   2009        WD        Abnorml     239686
# 1160       0      9   2009        WD         Normal     139000
# 1161       0      6   2007        WD         Normal     169500
# 1162       0      7   2007        WD         Normal     201000
# 1163     400      5   2010        WD         Normal     189000
# 1164       0      6   2006        WD         Normal     348000
# 1165       0      7   2009        WD         Normal     148500
# 1166       0      3   2007        WD         Normal     168000
# 1167       0      5   2009       COD        Abnorml     112000
#
# [1168 rows x 81 columns]

# %%
# Numeric data segregation
numeric_feature = [a for a in range(len(train.dtypes)) if train.dtypes[a] in ['int64','float64']]
numeric_data = train.iloc[:,numeric_feature]
numeric_data.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0   880          20     70.18561     7000            5            8
# 1  1147          20     70.18561    11200            6            5
# 2  1347          20     70.18561    20781            7            7
# 3  1081          20     80.00000    11040            6            7
# 4   229          20     70.00000     8521            5            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      WoodDeckSF  \
# 0       1978          2005        90.0         646    ...               0
# 1       1985          1985        85.0        1258    ...             165
# 2       1968          2003         0.0         297    ...               0
# 3       1971          2004       144.0         656    ...              55
# 4       1967          1967         0.0         842    ...               0
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 0            0              0          0            0         0        0
# 1           26              0          0            0         0        0
# 2           80              0        290            0         0        0
# 3            0              0        216            0         0        0
# 4            0              0          0            0         0        0
#
#    MoSold  YrSold  SalePrice
# 0       7    2009     136500
# 1       5    2006     180000
# 2       6    2006     262500
# 3      10    2008     145000
# 4       5    2010     125000
#
# [5 rows x 38 columns]

# %%
#Loading the data
NY_Housing = numeric_data

# making Independent and Dependent variables from the dataset
X = NY_Housing.iloc[:,:-1]
y = NY_Housing.SalePrice

# %%
# Fitting Multiple Linear Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)

print("intercept:", regressor.intercept_)
print("coefficients of predictors:", regressor.coef_)



# Predicting the results
y_pred = regressor.predict(X)
y_pred[:10]


prices = pd.DataFrame({"actual": y,
          "predicted": y_pred})
prices.head(10)
# Out:
# intercept: 269939.37594411196
# coefficients of predictors: [-1.08350927e+00 -1.97151981e+02 -1.09794300e+02  3.23257701e-01
#   1.77773310e+04  4.88404366e+03  3.65440261e+02  9.61097319e+01
#   1.93961403e+01  9.14024751e+00 -1.06757707e+00 -1.13322814e-01
#   7.95934762e+00  2.00959468e+01  2.62916132e+01 -2.07363599e+01
#   2.56512001e+01  1.04125132e+04  2.70219712e+03  2.72177839e+03
#  -5.01044814e+03 -8.26133382e+03 -1.06680073e+04  3.69146055e+03
#   4.48660281e+03 -1.59331551e+01  2.07640626e+04 -6.86754028e+00
#   3.33726648e+01 -2.11024402e+01  1.99657893e+01  3.98182820e+01
#   4.66631573e+01 -1.39634740e+01 -3.24737589e-01  2.15640743e+02
#  -6.03943137e+02]
#    actual      predicted
# 0  136500  132087.040161
# 1  180000  195789.853703
# 2  262500  261516.451308
# 3  145000  187156.524030
# 4  125000  103031.971348
# 5  110000  107942.627026
# 6  125500  106594.140628
# 7  272000  294155.393527
# 8   89500  100032.669435
# 9  173000  180624.724740
